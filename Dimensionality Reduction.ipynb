# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import seaborn
NHP=pandas.read_csv("NaN_Housing_Prices.csv")
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
NHP
# Out:
#        Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0        221900.0               3             1.00               1180.0
# 1        538000.0               3             2.25               2570.0
# 2        180000.0               2             1.00                770.0
# 3        604000.0               4             3.00               1960.0
# 4        510000.0               3             2.00               1680.0
# ...           ...             ...              ...                  ...
# 21604    360000.0               3             2.50               1530.0
# 21605    400000.0               4             2.50               2310.0
# 21606    402101.0               2             0.75               1020.0
# 21607    400000.0               3             2.50               1600.0
# 21608    325000.0               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# ...

# %% [markdown]
# # Missing Value Ratio

# %%
NHP.isnull().sum()
# Out:
# Sale_Price                                       0
# No of Bedrooms                                   0
# No of Bathrooms                                  0
# Flat Area (in Sqft)                              0
# Lot Area (in Sqft)                               0
# No of Floors                                     0
# No of Times Visited                          19485
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        0
# Basement Area (in Sqft)                      13123
# Age of House (in Years)                          0
# Latitude                                         0
# Longitude                                        0
# Living Area after Renovation (in Sqft)           0
# Lot Area after Renovation (in Sqft)              0
# Years Since Renovation                       20695
# Condition_of_the_House_Excellent                 0
# Condition_of_the_House_Fair                      0
# ...

# %% [markdown]
# ##### Removing columns with missing values:

# %%
for i in NHP.columns:
    tmp=NHP[i].isnull().sum()/len(NHP)
    if tmp>0.7:
        print("Dropping column ", i," with missing value ratio",tmp)
        NHP=NHP.drop(columns=[i])
# Out:
# Dropping column  No of Times Visited  with missing value ratio 0.9017076218242399
# Dropping column  Years Since Renovation  with missing value ratio 0.9577028090147623

# %% [markdown]
# # Low Variance

# %%
RHP=pandas.read_csv("Raw_Housing_Prices3.csv")
RHP
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21604   263000018         14 May 2017    360000.0               3
# 21605  6600060120    15 February 2016    400000.0               4
# 21606  1523300141        14 June 2017    402101.0               2
# 21607   291310100     15 January 2016    400000.0               3
# 21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
RHP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %% [markdown]
# ##### Drop all the columns which are not categorical:

# %%
numerical_data=RHP.drop(columns=['ID', 'Date House was Sold', 'Sale Price', 'Waterfront View', 'No of Times Visited', 
                                'Condition of the House', 'Overall Grade', 'Zipcode'])
numerical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   No of Bedrooms                             21609 non-null  int64
#  1   No of Bathrooms                            21609 non-null  float64
#  2   Flat Area (in Sqft)                        21609 non-null  float64
#  3   Lot Area (in Sqft)                         21609 non-null  float64
#  4   No of Floors                               21609 non-null  float64
#  5   Area of the House from Basement (in Sqft)  21609 non-null  float64
#  6   Basement Area (in Sqft)                    21609 non-null  int64
#  7   Age of House (in Years)                    21609 non-null  int64
#  8   Renovated Year                             21609 non-null  int64
#  9   Latitude                                   21609 non-null  float64
# ...

# %% [markdown]
# ##### Normalize all the numerical columns:

# %%
from sklearn.preprocessing import Normalizer
norm=Normalizer()
norm_data=norm.fit_transform(numerical_data)
norm_data=pandas.DataFrame(norm_data, columns=numerical_data.columns)
norm_data
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0            0.000363         0.000121             0.142628
# 1            0.000264         0.000198             0.226174
# 2            0.000152         0.000076             0.058440
# 3            0.000527         0.000395             0.258159
# 4            0.000263         0.000175             0.147072
# ...               ...              ...                  ...
# 21604        0.000922         0.000768             0.470018
# 21605        0.000401         0.000250             0.231383
# 21606        0.000667         0.000250             0.340207
# 21607        0.000788         0.000657             0.420407
# 21608        0.000807         0.000303             0.411714
#
#        Lot Area (in Sqft)  No of Floors  \
# 0                0.682924      0.000121
# 1                0.637335      0.000176
# 2                0.758961      0.000076
# 3                0.658569      0.000132
# ...

# %% [markdown]
# ##### Check the variance of the data:

# %%
tmp=norm_data.var()
tmp
# Out:
# No of Bedrooms                               4.071117e-08
# No of Bathrooms                              2.802492e-08
# Flat Area (in Sqft)                          1.231500e-02
# Lot Area (in Sqft)                           1.351803e-02
# No of Floors                                 3.008524e-08
# Area of the House from Basement (in Sqft)    1.010140e-02
# Basement Area (in Sqft)                      1.648493e-03
# Age of House (in Years)                      2.002344e-05
# Renovated Year                               1.684740e-03
# Latitude                                     1.077875e-05
# Longitude                                    7.109191e-05
# Living Area after Renovation (in Sqft)       1.079222e-02
# Lot Area after Renovation (in Sqft)          1.250016e-02
# dtype: float64

# %% [markdown]
# ##### Removing variables below the 1e-4 threshold:

# %%
T=1e-4

for i in tmp:
    if i<T:
        norm_data.drop(columns=[tmp[tmp==i].index[0]], inplace=True)
        
norm_data.var()
# Out:
# Flat Area (in Sqft)                          0.012315
# Lot Area (in Sqft)                           0.013518
# Area of the House from Basement (in Sqft)    0.010101
# Basement Area (in Sqft)                      0.001648
# Renovated Year                               0.001685
# Living Area after Renovation (in Sqft)       0.010792
# Lot Area after Renovation (in Sqft)          0.012500
# dtype: float64

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Creating x-train and y-train datasets for further procedures

# %%
data = pandas.read_csv('Transformed_Housing_Data2.csv')
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Y = data['Sale_Price']
X = scaler.fit_transform(data.drop(columns = ['Sale_Price']))
X = pandas.DataFrame(data = X, columns = data.drop(columns = ['Sale_Price']).columns)

X = data.drop(columns = ["Sale_Price"])
Y = data['Sale_Price']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 101)
X = data.drop(columns = ["Sale_Price"])
Y = data['Sale_Price']

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
lr.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %% [markdown]
# ##### The above codebox has been copied from the Linear Regression Notebook, refer it for more details.

# %% [markdown]
# ##### Now that we have created x_train and y_train sets, we can continue with dimensionality reduction

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Adjusted R:

# %%
predictions=lr.predict(x_test)
lr.score(x_test, y_test) #Calculated the R^2 value of the model
# Out:
# 0.846235554246878

# %%
def adj_r2(x, y, pred):
    from sklearn.metrics import r2_score
    R=r2_score(y, pred)
    n=len(y)
    m=len(x.columns)
    adjR=1-((n-1)*(1-R)/(n-(m+1)))
    return adjR

# %%
adj_r2(x_test, y_test, predictions)
# Out:
# 0.8455205924718325

# %% [markdown]
# ##### The difference in value is very low(0.001), this shows that there are some variables which are not contributing to the model

# %% [markdown]
# # Forward Selection

# %%
def adj_r2(m, y, pred):
    from sklearn.metrics import r2_score
    R=r2_score(y, pred)
    n=len(y)
    adjR=1-((n-1)*(1-R)/(n-(m+1)))
    return adjR

# %%
#Function to return value of adjR2 for an independent variable

def return_r2(X,Y,model):
    model.fit(X,Y)
    pred=model.predict(X)
    m=len(X.columns)
    return adj_r2(m, Y, model)

# %% [markdown]
# ### Main Function:

# %%
def forward_selection(model, X, Y, max_features):
    
    fcol=[]
    history=[]
    
    for i in range(max_features):
        
        fcol.append('blank')
        tmp=fcol[:]
        Rmax=-1
        
        for var in X.columns:
            tmp[-1]=var
            r2=return_r2(X[tmp], var, model)
            if r2>Rmax:
                fcol[-1]=var
                Rmax=r2
                elim=var
                
        print("Selected ",fcol[-1],"with new r2=", Rmax)
        history.append(Rmax)
        
    return Rmax, history, X[fcol]

# %%
score, history, sel_data= forward_selection(lr, x_train, y_train, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-1c402511a7c9> in <module>
# ----> 1 score, history, sel_data= forward_selection(lr, x_train, y_train, 5)
#
# <ipython-input-62-21587ba9e7e1> in forward_selection(model, X, Y, max_features)
#      12         for var in X.columns:
#      13             tmp[-1]=var
# ---> 14             r2=return_r2(X[tmp], var, model)
#      15             if r2>Rmax:
#      16                 fcol[-1]=var
#
# <ipython-input-61-911126646f2f> in return_r2(X, Y, model)
#       2
#       3 def return_r2(X,Y,model):
# ----> 4     model.fit(X,Y)
#       5     pred=model.predict(X)
#       6     m=len(X.columns)
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# ...

# %%
x_train
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 17219               4             2.25               2500.0
# 8520                2             1.00               1170.0
# 13009               4             2.75               2950.0
# 2640                3             1.00                910.0
# 16600               2             1.50               1310.0
# ...               ...              ...                  ...
# 5695                2             2.00               1660.0
# 8006                3             2.50               3190.0
# 17745               3             1.00               1410.0
# 17931               4             1.75               1980.0
# 13151               4             2.25               1830.0
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 17219              8500.0           2.0                    0              8
# 8520               5150.0           1.0                    0              6
# ...
